# %% [markdown]
# # Populate RAG Index
#
# Run this notebook to populate some data so that less online scraping is needed.

# %%
# logging imports
import logging
from logging import StreamHandler

# toolkit import
from kruppe.llm import OpenAIEmbeddingModel
from kruppe.functional.docstore.mongo_store import MongoDBStore
from kruppe.functional.rag.vectorstore.chroma import ChromaVectorStore
from kruppe.functional.rag.index.vectorstore_index import VectorStoreIndex
from kruppe.functional.newshub import NewsHub
from kruppe.data_source.news.nyt import NewYorkTimesData
from kruppe.data_source.news.ft import FinancialTimesData
from kruppe.data_source.news.newsapi import NewsAPIData

# console handler
ch = StreamHandler()
formatter = logging.Formatter('%(asctime)s - %(filename)-10s - %(levelname)-8s: %(message)s')
ch.setFormatter(formatter)
ch.setLevel(logging.INFO)

# file handler for scraper
scraper_log_file_path = '/Users/danielliu/Workspace/fin-rag/logs/scraper.log'
with open (scraper_log_file_path, 'w') as f:
    pass # create the file if it doesn't exist; clear it if it does

fh = logging.FileHandler(scraper_log_file_path)
fh.setFormatter(formatter)
fh.setLevel(logging.DEBUG)

# root logger
root_logger = logging.getLogger("kruppe")
root_logger.setLevel(logging.INFO)
root_logger.addHandler(ch)

# scraper logger
scraper_logger = logging.getLogger('kruppe.data_source.scraper')
scraper_logger.setLevel(logging.DEBUG)
scraper_logger.addHandler(fh)
# propagate is true

# %%
reset_db=True

db_name = "kruppe_librarian"
collection_name = "general_news_04_20_2025"

# Create doc store
unique_indices = [['title', 'datasource']] # NOTE: this is important to avoid duplicates
docstore = await MongoDBStore.acreate_db(
    db_name=db_name,
    collection_name=collection_name,
    unique_indices=unique_indices,
    reset_db=reset_db
)

# Create vectorstore index
embedding_model = OpenAIEmbeddingModel()
vectorstore = ChromaVectorStore(
    embedding_model=embedding_model,
    collection_name=collection_name,
    persist_path='/Volumes/Lexar/Daniel Liu/vectorstores/kruppe_librarian'
)

if reset_db:
    vectorstore.clear()
    
index = VectorStoreIndex(vectorstore=vectorstore)

# %%
news_hub = NewsHub(news_sources=[
    NewYorkTimesData(headers_path="../../.nyt-headers.json"),
    FinancialTimesData(headers_path="../../.ft-headers.json"),
    NewsAPIData()
])

# %%
df_news, docs = await news_hub.news_recent(
    days=100,
    max_results=500,
)
# Out:
# 2025-04-20 14:21:18,798 - ft.py      - INFO    : Fetching news feed from 2025-01-10 to 2025-04-20
# 2025-04-20 14:21:19,190 - newsapi.py - INFO    : Fetched 115 documents from NewsAPI API... Attempting to scrape.
# 2025-04-20 14:21:20,761 - scraper.py - WARNING : [httpx] Failed to scrape https://www.forbes.com/sites/daveywinder/2025/04/19/new-gmail-warning---do-not-open-this-email-from-google/ : HTTPStatusError("Redirect response '301 Moved Permanently' for url 'https://www.forbes.com/sites/daveywinder/2025/04/19/new-gmail-warning---do-not-open-this-email-from-google/'\nRedirect location: '/sites/daveywinder/2025/04/20/new-gmail-warning---do-not-open-this-email-from-google/'\nFor more information check: https://developer.mozilla.org/en-US/docs/Web/HTTP/Status
\nFor more information check: https://developer.mozilla.org/en-US/docs/Web/HTTP/Status/403")
# 2025-04-20 14:22:49,297 - scraper.py - WARNING : [httpx] Failed to scrape https://www.nytimes.com/video/embedded/us/100000010108688/00vid-xp-conteam-92022.html : HTTPStatusError("Client error '410 Gone' for url 'https://www.nytimes.com/video/embedded/us/100000010108688/00vid-xp-conteam-92022.html'\nFor more information check: https://developer.mozilla.org/en-US/docs/Web/HTTP/Status/410")
# 2025-04-20 14:22:52,180 - scraper.py - WARNING : [httpx] Failed to scrape https://static01.nyt.com/slideshow/2025/04/15/world/what-in-the-world/149th-annual-westminster-kennel-club-dog-show.html : HTTPStatusError("Client error '403 Forbidden' for url 'https://static01.nyt.com/slideshow/2025/04/15/world/what-in-the-world/149th-annual-westminster-kennel-club-dog-show.html'\nFor more information check: https://developer.mozilla.org/en-US/docs/Web/HTTP/Status/403")

# %%
print(f"Found {len(docs)} documents")

saved_docs = await docstore.asave_documents(docs)
print(f"Saved {len(saved_docs)} documents to MongoDB")

await index.async_add_documents(saved_docs)
print("Finished adding documents to vectorstore index")
# Out:
# Found 1084 documents
# 2025-04-20 14:22:58,558 - mongo_store.py - WARNING : Partial success with inserted count: 1078
# 2025-04-20 14:22:58,560 - mongo_store.py - WARNING : Write error: {'index': 20, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: kruppe_librarian.general_news_04_20_2025 index: title_1_datasource_1 dup key: { title: "", datasource: "NewsAPIData" }', 'keyPattern': {'title': 1, 'datasource': 1}, 'keyValue': {'title': '', 'datasource': 'NewsAPIData'}, 'op': {'text': "Earlier this week the NVIDIA GeForce RTX 5060 Ti launched and there were launch-day Linux CUDA/OpenCL compute benchmarks on Phoronix. But for the Linux gaming performance tests we were waiting on a new supported driver release, which happened to be on launch day with the NVIDIA 575.51.02 Linux beta . Now that the gaming-ready Linux driver is available for the GeForce RTX 5060 series, here are some initial benchmarks of the PNY GeForce RTX 5060 Ti 16GB up against other NVIDIA GeForce and AMD Radeon graphics cards using the newly-released Ubuntu 25.04.\n\nThe NVIDIA GeForce RTX 5060 Ti began shipping on Wednesday with the 16GB variant slated for a  $429 USD starting price. Now two days later, many of the RTX 5060 Ti 16GB listings at major Internet retails are out-of-stock. For those that I were able to find in-stock as of writing on Friday, there were some at $480 USD but most of the listings with availability still were in the $499~549 range. Availability of the 8GB RTX 5060 Ti seems to be even tighter or more limited in general with most gamers in 2025 being much better off going for the 16GB version.\n\nThe NVIDIA GeForce RTX 5060 Ti as a reminder has 4608 CUDA cores, 16GB of GDDR7 video memory with a 128-bit memory interface, 2.41GHz base clock, and 2.57GHz boost clock. The GeForce RTX 5060 series carries all the common NVIDIA Blackwell GPU features like DLSS 4 support, latest NVENC and NVDEC blocks, PCI Express Gen 5.0 connectivity, and DisplayPort 2.1b support.\n\nThe GeForce RTX 5060 Ti has a 180 Watt graphics power rating and requires a single PCI Express 8-pin power connection or PCIe Gen 5 cable depending upon the AIB model. As mentioned in the prior compute tests, NVIDIA kindly supplied a PNY GeForce RTX 5060 Ti 16GB model for this launch-day testing on Phoronix.\nPhoronix Premium allows ad-free access to the site, multi-page articles on a single page, and other features while supporting this site's continued operations.\nThe mission at Phoronix since 2004 has centered around enriching the Linux hardware experience. In addition to supporting our site through advertisements, you can help by subscribing to Phoronix Premium . You can also contribute to Phoronix through a PayPal tip or tip via Stripe .\n\nLegal Disclaimer, Privacy Policy, Cookies | Privacy Manager | Contact\nCopyright © 2004 - 2025 by Phoronix Media .\nAll trademarks used are properties of their respective owners. All rights reserved.", 'uuid': UUID('da1fa00a-4db6-4b63-90ad-448e31a6fd72'), 'query': '', 'datasource': 'NewsAPIData', 'url': 'https://www.phoronix.com/review/nvidia-rtx-5060ti-linux-gaming', 'title': '', 'description': '', 'publication_time': '', 'source': 'Phoronix', 'document_type': '', 'tags': '', 'author': '', '_id': ObjectId('68053b80a0cc536d4f9e94e4')}}
# 2025-04-20 14:22:58,560 - mongo_store.py - WARNING : Write error: {'index': 71, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: kruppe_librarian.general_news_04_20_2025 index: title_1_datasource_1 dup key: { title: "", datasource: "NewsAPIData" }', 'keyPattern': {'title': 1, 'datasource': 1}, 'keyValue': {'title': '', 'datasource': 'NewsAPIData'}, 'op': {'text': 'Rose Dixon\n04/19/2025\nThe discovery of a massive gold deposit in China has sent shockwaves through the global mining industry . Geologists from the Hunan Provincial Geological Bureau (HPGB) have uncovered what may be the world’s largest gold reserve, with an estimated value of approximately €76 billion. This extraordinary find not only highlights China’s growing dominance in the precious metals sector but also raises questions about the environmental and economic implications of such a discovery.\nIn late 2024, Chinese state media agency Xinhua reported an extraordinary discovery beneath the Wangu gold field in Hunan province. The geological survey team identified 40 new gold veins containing an estimated 1,100 tonnes of precious metal. This discovery potentially surpasses the previous record holder, South Africa’s South Deep mine, which holds approximately 930 tonnes of recoverable gold.\nThe quality of the deposit appears exceptional, with reports indicating that each tonne of ore contains up to 138 grams of gold – a concentration significantly higher than typical mining operations. At current market values, officials from the Hunan Provincial Geological Bureau estimate the deposit’s worth at around 600 billion yuan (€76 billion).\nSuch massive discoveries are becoming increasingly rare in a world where easily accessible gold deposits have largely been exploited. This find represents a significant boost to China’s domestic reserves, though the challenges of extracting gold from depths of 2,000-3,000 meters should not be underestimated. Like deep-sea discoveries that challenge our understanding of extreme environments , this gold find demonstrates how unexplored regions can still yield remarkable treasures.\nDespite being the world’s leading gold producer, contributing approximately 10% of global output, China consumes roughly three times more gold than it mines. This imbalance explains why such a discovery, while significant, would only satisfy the country’s gold appetite for approximately 18 months.\nAccording to recent Statista data, China currently ranks sixth globally in terms of gold reserves with approximately 3,100 tonnes. This positions the country well behind Australia and Russia, both estimated to hold around 12,000 tonnes each, and South Africa with approximately 5,000 tonnes.\nThe discovery could significantly impact regional economies and ecosystems. Just as major environmental events can threaten wildlife habitats , large-scale mining operations often present ecological challenges that require careful management.\nChinese geologists have detailed that their exploration revealed 330 tonnes of gold at approximately 2,000 meters depth, with modeling suggesting an additional 770 tonnes may exist 1,000 meters deeper. This stratification of resources presents both opportunities and challenges for extraction technology .\nWhile the economic potential of this discovery is undeniable, significant environmental concerns accompany any major mining operation. Gold extraction typically involves processes that can release toxic substances into surrounding ecosystems if not properly managed. Deforestation and habitat disruption represent additional environmental costs that must be factored into development plans.\nChinese authorities will need to balance economic benefits against ecological impacts, particularly as researchers continually identify mechanisms that threaten species survival . The mining sector’s environmental footprint has come under increasing scrutiny worldwide, with particular attention to water usage and chemical management.\nThe ...
# 2025-04-20 14:22:58,561 - mongo_store.py - WARNING : Write error: {'index': 249, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: kruppe_librarian.general_news_04_20_2025 index: title_1_datasource_1 dup key: { title: "FTAV’s further reading", datasource: "FinancialTimesData" }', 'keyPattern': {'title': 1, 'datasource': 1}, 'keyValue': {'title': 'FTAV’s further reading', 'datasource': 'FinancialTimesData'}, 'op': {'text': '\nLouis Ashworth\nPublished April 15 2025\nElsewhere on Tuesday…\n— How Bloomberg — and ‘Bloomberg’ — drove markets and headlines (Semafor)\n— Welcome to the Kaibab Plateau (Car Charts)\n— OpenAI is a systemic risk to the tech industry (Where’s Your Ed At?)\n— The post-developer era (Josh W Comeau)\n— The unbearable loudness of chewing (Asterisk, bearable Mouthchew here )\n— Another quick post on buffer ETFs (Basis Pointing)\n— The limits to growth… are coming closer (Klement on Investing)', 'uuid': UUID('ce8a4443-663b-4632-ade1-1521fcfd05c4'), 'query': '', 'datasource': 'FinancialTimesData', 'url': 'https://www.ft.com/content/04141235-4c75-44b7-8949-d5eae9e7419d', 'title': 'FTAV’s further reading', 'description': 'Bloomberg vs Bloomberg; cars; OpenAI; devs; chewing; buffer ETFs; and growth', 'publication_time': 1744695046, 'document_type': 'article', 'tags': 'FT Alphaville', 'author': 'Louis Ashworth', '_id': ObjectId('68053b80a0cc536d4f9e95c9')}}
# 2025-04-20 14:22:58,564 - mongo_store.py - WARNING : Write error: {'index': 281, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: kruppe_librarian.general_news_04_20_2025 index: title_1_datasource_1 dup key: { title: "Are we on the brink of a nuclear revival? | FT Film", datasource: "FinancialTimesData" }', 'keyPattern': {'title': 1, 'datasource': 1}, 'keyValue': {'title': 'Are we on the brink of a nuclear revival? | FT Film', 'datasource': 'FinancialTimesData'}, 'op': {'text': "The electricity needed to power huge data centres has sparked a renewed interest in the potential of small modular reactors. The FT's Pilita Clark looks at whether SMRs will help with the clean energy transition\nProduced & edited by Tom Hannen. Cameras: Petros Gioumpasis, Ian Kerr, Neil Barrett, Richard van Rijn\nYou can enable subtitles (captions) in the video player\nAre we on the brink of a nuclear revival?\nLately, we've been hearing a lot about this concept of small modular nuclear reactors.\nSMRs are the future of nuclear power generation. We need all the nuclear power we can if the world has a hope of getting to net zero by 2050.\nIt won't be cheaper than the big ones, and the big ones are already the most expensive electricity we've ever known.\nThe demand for cloud storage and AI has gone up enormously. And that's why these tech companies are so interested in stable nuclear power.\nEnvironmentalists should acknowledge that nuclear power is not the devil that they have held nuclear power to be.\nIt was going to generate cheap electricity. That's ultimately the promise. That has simply not happened.\nI think nuclear industry has a bad name because it has wasted so many taxpayer dollars over time, and no one has ever apologised for it.\n\n\nIt's sometimes hard to grasp just how much power is gobbled up constantly by computer servers like these. These devices, they look so small, almost weightless, just a slab of glass. But everything you do on them, every email you send, every purchase you make, every movie you download is handled by vast physical data centres filled with servers like these. And the demand for power that's required could increase significantly as AI takes off. But where that new electricity is going to come from is still an open question.\nThe industry has been talking about a nuclear renaissance for about 25 years. Don't believe it. Since 2000, some 120 reactors or so have come online in the same period. That same number of reactors have been shut down permanently.\nIf you look at the share of electricity produced in the world, that was around 17 per cent in the mid-1990s. Today, it's only 9 per cent. This is not what a nuclear renaissance looks like. World leaders are promising and making pledges to triple nuclear capacity. All this is great, but so far it's just words. And for a nuclear revival, we will need more than words. We need to build.\nI think we are experiencing one more cycle of talk about nuclear renaissance. We've seen this kind of cycle happen before. For example, in the beginning of the century, under both Tony Blair government in the UK and the George Bush administration in the United States, there was a lot of talk about nuclear renaissance. There were about 30 reactors ordered by utility companies around the United States.\nIn fact, only four of them went into construction. And of those four, two of them were abandoned after about $9bn were spent. The hype never seems to match with the reality.\nWe will not be able to solve global warming if we don't increase our use of nuclear power spectacularly. And this will be hard, given the dominance of fossil fuel companies and given the popularity of wind and solar.\nThe average nuclear plant takes about 10 years between the time you start pouring concrete in the ground and it starts generating power and supplying it to the grid. But usually there's another period of five or 10 years that is required to get the environmental clearances, to get the saf ...
# 2025-04-20 14:22:58,567 - mongo_store.py - WARNING : Write error: {'index': 294, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: kruppe_librarian.general_news_04_20_2025 index: title_1_datasource_1 dup key: { title: "FTAV’s further reading", datasource: "FinancialTimesData" }', 'keyPattern': {'title': 1, 'datasource': 1}, 'keyValue': {'title': 'FTAV’s further reading', 'datasource': 'FinancialTimesData'}, 'op': {'text': '\nLouis Ashworth\nPublished April 16 2025\nElsewhere on Wednesday…\n— The plight of the taxman (New Yorker)\n— OpenAI is building a social network (The Verge)\n— Liz Truss to launch ‘uncensored’ social network to counter mainstream media (The Guardian)\n— Tax privacy (Conversable Economist)\n— A roadmap to alien worlds (Noema)\n— The unreality of reality TV (Nieman Lab)\n— Pentagon’s ‘SWAT team of nerds’ resigns en masse (Politico)', 'uuid': UUID('1532a242-e190-4a0e-91b7-081257ea5b33'), 'query': '', 'datasource': 'FinancialTimesData', 'url': 'https://www.ft.com/content/fb5973a4-6df6-463f-9096-aee1d5b17626', 'title': 'FTAV’s further reading', 'description': 'Tax; social networks that make you go hmmmm; more tax; aliens; reality TV; and ‘SWAT’ nerds', 'publication_time': 1744781454, 'document_type': 'article', 'tags': 'FT Alphaville', 'author': 'Louis Ashworth', '_id': ObjectId('68053b80a0cc536d4f9e95f6')}}
# 2025-04-20 14:22:58,568 - mongo_store.py - WARNING : Write error: {'index': 400, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: kruppe_librarian.general_news_04_20_2025 index: title_1_datasource_1 dup key: { title: "FTAV’s further reading", datasource: "FinancialTimesData" }', 'keyPattern': {'title': 1, 'datasource': 1}, 'keyValue': {'title': 'FTAV’s further reading', 'datasource': 'FinancialTimesData'}, 'op': {'text': '\nLouis Ashworth\nPublished April 18 2025\nPub quiz, get yer tickets to the pub quiz . Elsewhere on Friday…\n— How a forgotten battle created a more peaceful world (Looking Through the Past)\n— This ‘college protester’ isn’t real. It’s an AI-powered undercover bot for cops (Wired)\n— Are you a good estimator? (Dylan Castillo)\n— Compliance is the new American dream (Kyla’s Newsletter)\n— A millennial saint (Harper’s Magazine)\n— How a secretive gambler called ‘The Joker’ took down the Texas lottery (Wall Street Journal)\n— Why the ‘weakest samurai warlord’ is admired to this day (Tokyo Weekender)\n— Toby Carvery owner ‘sorry’ over ancient tree felling (BBC News)', 'uuid': UUID('43991d5a-d732-475d-92b1-606c91745050'), 'query': '', 'datasource': 'FinancialTimesData', 'url': 'https://www.ft.com/content/564e0a15-c2ef-4216-8db6-20cb80d4d0b7', 'title': 'FTAV’s further reading', 'description': 'A battle; a protester; an estimator; a dream; a saint; a gambler; a samurai; and a Toby Carvery', 'publication_time': 1744954232, 'document_type': 'article', 'tags': 'FT Alphaville', 'author': 'Louis Ashworth', '_id': ObjectId('68053b80a0cc536d4f9e9660')}}
# Saved 1078 documents to MongoDB
# 2025-04-20 14:23:02,558 - chroma.py  - INFO    : Inserting documents into ChromaDB
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# Cell In[5], line 6
#       3 saved_docs = await docstore.asave_documents(docs)
#       4 print(f"Saved {len(saved_docs)} documents to MongoDB")
# ----> 6 await index.async_add_documents(saved_docs)
#       7 print("Finished adding documents to vectorstore index")
#
# File ~/Workspace/fin-rag/src/kruppe/functional/rag/index/vectorstore_index.py:31, in VectorStoreIndex.async_add_documents(self, documents)
#      29 chunked_documents = await self.text_splitter.async_split_documents(documents)
#      30 # insert documents into vector store
# ---> 31 await self.vectorstore.async_insert_documents(chunked_documents)
#
# File ~/Workspace/fin-rag/src/kruppe/functional/rag/vectorstore/chroma.py:123, in ChromaVectorStore.async_insert_documents(self, documents)
#     121 # insert data into chromadb
#     122 logger.info("Inserting documents into ChromaDB")
# --> 123 self._collection.upsert(
#     124     ids=data["ids"],
#     125     metadatas=data["metadatas"],
#     126     documents=data["documents"],
#     127     embeddings=data["embeddings"],
#     128 )
#     130 return data["ids"]
#
# File ~/Library/Application Support/hatch/env/virtual/kruppe/SC07CWML/experimental/lib/python3.13/site-packages/chromadb/api/models/Collection.py:345, in Collection.upsert(self, ids, embeddings, metadatas, documents, images, uris)
#     325 """Update the embeddings, metadatas or documents for provided ids, or create them if they don't exist.
#     326
#     327 Args:
#    (...)    334     None
#     335 """
#     336 upsert_request = self._validate_and_prepare_upsert_request(
#     337     ids=ids,
#     338     embeddings=embeddings,
#    (...)    342     uris=uris,
#     343 )
# --> 345 self._client._upsert(
#     346     collection_id=self.id,
#     347     ids=upsert_request["ids"],
#     348     embeddings=upsert_request["embeddings"],
#     349     metadatas=upsert_request["metadatas"],
#     350     documents=upsert_request["documents"],
#     351     uris=upsert_request["uris"],
#     352     tenant=self.tenant,
#     353     database=self.database,
#     354 )
#
# File ~/Library/Application Support/hatch/env/virtual/kruppe/SC07CWML/experimental/lib/python3.13/site-packages/chromadb/api/rust.py:455, in RustBindingsAPI._upsert(self, collection_id, ids, embeddings, metadatas, documents, uris, tenant, database)
#     443 @override
#     444 def _upsert(
#     445     self,
#    (...)    453     database: str = DEFAULT_DATABASE,
#     454 ) -> bool:
# --> 455     return self.bindings.upsert(
#     456         str(collection_id),
#     457         ids,
#     458         embeddings,
#     459         metadatas,
#     460         documents,
#     461         uris,
#     462         tenant,
#     463         database,
#     464     )
#
# InternalError: ValueError: Batch size of 8820 is greater than max batch size of 5461
